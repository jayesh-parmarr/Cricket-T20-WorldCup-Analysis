# %%
import pandas as pd
import numpy as np

# %%
wc_2007 = pd.read_csv("C:/Users/HP/Desktop/t20/T20 World Cups/T20 World Cup 2007 matches.csv")
wc_2009 = pd.read_csv("C:/Users/HP/Desktop/t20/T20 World Cups/T20 World Cup 2009 matches.csv")
wc_2010 = pd.read_csv("C:/Users/HP/Desktop/t20/T20 World Cups/T20 World Cup 2010 matches.csv")
wc_2012 = pd.read_csv("C:/Users/HP/Desktop/t20/T20 World Cups/T20 World Cup 2012 matches.csv")
wc_2014 = pd.read_csv("C:/Users/HP/Desktop/t20/T20 World Cups/T20 World Cup 2014 matches.csv")
wc_2016 = pd.read_csv("C:/Users/HP/Desktop/t20/T20 World Cups/T20 World Cup 2016 matches.csv")
wc_2021 = pd.read_csv("C:/Users/HP/Desktop/t20/T20 World Cups/T20 World Cup 2021 matches.csv")
wc_2022 = pd.read_csv("ICC Mens T20 World Cup 2022.csv")

# %% [markdown]
# wc_2007

# %%
wc_2007.head()
# Out:
#    Match No        Date Group/Semi Final/Final                Match Between  \
# 0         1  2007-11-09                Group A  South Africa vs West Indies
# 1         2  2007-12-09                Group C         Kenya vs New Zealand
# 2         3  2007-12-09                Group D         Pakistan vs Scotland
# 3         4  2007-12-09                Group B        Australia vs Zimbabwe
# 4         5  2007-09-13                Group A    Bangladesh vs West Indies
#
#                                  Venue Winning Team Score Losing Team Score  \
# 0  The Wanderers Stadium, Johannesburg  208/2(17.4 overs)   205/6(20 overs)
# 1                    Kingsmead, Durban    74/1(7.4 overs)    73(16.5 overs)
# 2                    Kingsmead, Durban    171/9(20 overs)   120(19.5 overs)
# 3                  Newlands, Cape Town  139/5(19.5 overs)   138/9(20 overs)
# 4  The Wanderers Stadium, Johannesburg    165/4(18 overs)   164/8(20 overs)
#
# ...

# %%
wc_2007.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Match No                27 non-null     int64
#  1   Date                    27 non-null     object
#  2   Group/Semi Final/Final  27 non-null     object
#  3   Match Between           27 non-null     object
#  4   Venue                   27 non-null     object
#  5   Winning Team Score      26 non-null     object
#  6   Losing Team Score       26 non-null     object
#  7   Winner Team             26 non-null     object
#  8   Result                  27 non-null     object
#  9   Player Of The Match     26 non-null     object
# dtypes: int64(1), object(9)
# memory usage: 2.2+ KB

# %%
wc_2007
# Out:
#     Match No        Date Group/Semi Final/Final                Match Between  \
# 0          1  2007-11-09                Group A  South Africa vs West Indies
# 1          2  2007-12-09                Group C         Kenya vs New Zealand
# 2          3  2007-12-09                Group D         Pakistan vs Scotland
# 3          4  2007-12-09                Group B        Australia vs Zimbabwe
# 4          5  2007-09-13                Group A    Bangladesh vs West Indies
# 5          6  2007-09-13                Group B          England vs Zimbabwe
# 6          7  2007-09-13                Group D            India vs Scotland
# 7          8  2007-09-14                Group C           Kenya vs Sri Lanka
# 8          9  2007-09-14                Group B         Australia vs England
# 9         10  2007-09-14                Group D            India vs Pakistan
# 10        11  2007-09-15                Group C     New Zealand vs Sri Lanka
# ...

# %% [markdown]
# Filling missing value with 'NO' as some match are not played

# %%
wc_2007.fillna('NO',inplace=True)

# %%
wc_2007.isna().sum()
# Out:
# Match No                  0
# Date                      0
# Group/Semi Final/Final    0
# Match Between             0
# Venue                     0
# Winning Team Score        0
# Losing Team Score         0
# Winner Team               0
# Result                    0
# Player Of The Match       0
# dtype: int64

# %% [markdown]
# making two more columns 'team1' and 'team2' from 'Match Between' column

# %%
wc_2007['Team1'], wc_2007['Team2'] = wc_2007['Match Between'].str.split(' vs ',1).str
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16648\2774212848.py:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   wc_2007['Team1'], wc_2007['Team2'] = wc_2007['Match Between'].str.split(' vs ',1).str
# C:\Users\HP\AppData\Local\Temp\ipykernel_16648\2774212848.py:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   wc_2007['Team1'], wc_2007['Team2'] = wc_2007['Match Between'].str.split(' vs ',1).str

# %%
wc_2007.head()
# Out:
#    Match No        Date Group/Semi Final/Final                Match Between  \
# 0         1  2007-11-09                Group A  South Africa vs West Indies
# 1         2  2007-12-09                Group C         Kenya vs New Zealand
# 2         3  2007-12-09                Group D         Pakistan vs Scotland
# 3         4  2007-12-09                Group B        Australia vs Zimbabwe
# 4         5  2007-09-13                Group A    Bangladesh vs West Indies
#
#                                  Venue Winning Team Score Losing Team Score  \
# 0  The Wanderers Stadium, Johannesburg  208/2(17.4 overs)   205/6(20 overs)
# 1                    Kingsmead, Durban    74/1(7.4 overs)    73(16.5 overs)
# 2                    Kingsmead, Durban    171/9(20 overs)   120(19.5 overs)
# 3                  Newlands, Cape Town  139/5(19.5 overs)   138/9(20 overs)
# 4  The Wanderers Stadium, Johannesburg    165/4(18 overs)   164/8(20 overs)
#
# ...

# %% [markdown]
# we have team1 and team2 and winner team it would be easier for us if we have losing team column to

# %%
wc_2007['Losing Team'] = np.where(wc_2007['Winner Team']==wc_2007['Team1'], wc_2007['Team2'], wc_2007['Team1'])

# %%
wc_2007.loc[(wc_2007['Winner Team'] != wc_2007['Team1']) & (wc_2007['Winner Team'] != wc_2007['Team2']), 'Losing Team'] = 'NO'

# %%
wc_2007.head()
# Out:
#    Match No        Date Group/Semi Final/Final                Match Between  \
# 0         1  2007-11-09                Group A  South Africa vs West Indies
# 1         2  2007-12-09                Group C         Kenya vs New Zealand
# 2         3  2007-12-09                Group D         Pakistan vs Scotland
# 3         4  2007-12-09                Group B        Australia vs Zimbabwe
# 4         5  2007-09-13                Group A    Bangladesh vs West Indies
#
#                                  Venue Winning Team Score Losing Team Score  \
# 0  The Wanderers Stadium, Johannesburg  208/2(17.4 overs)   205/6(20 overs)
# 1                    Kingsmead, Durban    74/1(7.4 overs)    73(16.5 overs)
# 2                    Kingsmead, Durban    171/9(20 overs)   120(19.5 overs)
# 3                  Newlands, Cape Town  139/5(19.5 overs)   138/9(20 overs)
# 4  The Wanderers Stadium, Johannesburg    165/4(18 overs)   164/8(20 overs)
#
# ...

# %% [markdown]
# we dont need Team1 and Team2 as we can use Winner Team and Losing Team, we can drop them but im keeping it, it might be helpfull later or else will drop no issues

# %% [markdown]
# our date column is in object type i.e string lets convert it into datetype

# %%
wc_2007['Date'] = pd.to_datetime(wc_2007['Date'])

# %%
wc_2007.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Match No                27 non-null     int64
#  1   Date                    27 non-null     datetime64[ns]
#  2   Group/Semi Final/Final  27 non-null     object
#  3   Match Between           27 non-null     object
#  4   Venue                   27 non-null     object
#  5   Winning Team Score      27 non-null     object
#  6   Losing Team Score       27 non-null     object
#  7   Winner Team             27 non-null     object
#  8   Result                  27 non-null     object
#  9   Player Of The Match     27 non-null     object
#  10  Team1                   27 non-null     object
#  11  Team2                   27 non-null     object
#  12  Losing Team             27 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(11)
# memory usage: 2.9+ KB

# %%
wc_2007
# Out:
#     Match No       Date Group/Semi Final/Final                Match Between  \
# 0          1 2007-11-09                Group A  South Africa vs West Indies
# 1          2 2007-12-09                Group C         Kenya vs New Zealand
# 2          3 2007-12-09                Group D         Pakistan vs Scotland
# 3          4 2007-12-09                Group B        Australia vs Zimbabwe
# 4          5 2007-09-13                Group A    Bangladesh vs West Indies
# 5          6 2007-09-13                Group B          England vs Zimbabwe
# 6          7 2007-09-13                Group D            India vs Scotland
# 7          8 2007-09-14                Group C           Kenya vs Sri Lanka
# 8          9 2007-09-14                Group B         Australia vs England
# 9         10 2007-09-14                Group D            India vs Pakistan
# 10        11 2007-09-15                Group C     New Zealand vs Sri Lanka
# ...

# %% [markdown]
# extracting runs and overs of winning team

# %%
wc_2007['Winning Team Runs'] = wc_2007['Winning Team Score'].str.extract(r'(\d+)')
wc_2007['Winning Team Over Played']=wc_2007['Winning Team Score'].str.extract(r'\((\d+(?:\.\d{1,2})?) overs\)')

# %% [markdown]
# extracting runs and overs of losing team

# %%
wc_2007['Losing Team Runs'] = wc_2007['Losing Team Score'].str.extract(r'(\d+)')
wc_2007['Losing Team Over Played']=wc_2007['Losing Team Score'].str.extract(r'\((\d+(?:\.\d{1,2})?) overs\)')

# %%
wc_2007
# Out:
#     Match No       Date Group/Semi Final/Final                Match Between  \
# 0          1 2007-11-09                Group A  South Africa vs West Indies
# 1          2 2007-12-09                Group C         Kenya vs New Zealand
# 2          3 2007-12-09                Group D         Pakistan vs Scotland
# 3          4 2007-12-09                Group B        Australia vs Zimbabwe
# 4          5 2007-09-13                Group A    Bangladesh vs West Indies
# 5          6 2007-09-13                Group B          England vs Zimbabwe
# 6          7 2007-09-13                Group D            India vs Scotland
# 7          8 2007-09-14                Group C           Kenya vs Sri Lanka
# 8          9 2007-09-14                Group B         Australia vs England
# 9         10 2007-09-14                Group D            India vs Pakistan
# 10        11 2007-09-15                Group C     New Zealand vs Sri Lanka
# ...

# %%
wc_2007.fillna(0,inplace=True)

# %%
wc_2007
# Out:
#     Match No       Date Group/Semi Final/Final                Match Between  \
# 0          1 2007-11-09                Group A  South Africa vs West Indies
# 1          2 2007-12-09                Group C         Kenya vs New Zealand
# 2          3 2007-12-09                Group D         Pakistan vs Scotland
# 3          4 2007-12-09                Group B        Australia vs Zimbabwe
# 4          5 2007-09-13                Group A    Bangladesh vs West Indies
# 5          6 2007-09-13                Group B          England vs Zimbabwe
# 6          7 2007-09-13                Group D            India vs Scotland
# 7          8 2007-09-14                Group C           Kenya vs Sri Lanka
# 8          9 2007-09-14                Group B         Australia vs England
# 9         10 2007-09-14                Group D            India vs Pakistan
# 10        11 2007-09-15                Group C     New Zealand vs Sri Lanka
# ...

# %%
wc_2007.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Match No                  27 non-null     int64
#  1   Date                      27 non-null     datetime64[ns]
#  2   Group/Semi Final/Final    27 non-null     object
#  3   Match Between             27 non-null     object
#  4   Venue                     27 non-null     object
#  5   Winning Team Score        27 non-null     object
#  6   Losing Team Score         27 non-null     object
#  7   Winner Team               27 non-null     object
#  8   Result                    27 non-null     object
#  9   Player Of The Match       27 non-null     object
#  10  Team1                     27 non-null     object
#  11  Team2                     27 non-null     object
#  12  Losing Team               27 non-null     object
# ...

# %%
wc_2007['Winning Team Runs'] = pd.to_numeric(wc_2007['Winning Team Runs'])
wc_2007['Winning Team Over Played'] = pd.to_numeric(wc_2007['Winning Team Over Played'])
wc_2007['Losing Team Runs'] = pd.to_numeric(wc_2007['Losing Team Runs'])
wc_2007['Losing Team Over Played'] = pd.to_numeric(wc_2007['Losing Team Over Played'])

# %%
wc_2007.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Match No                  27 non-null     int64
#  1   Date                      27 non-null     datetime64[ns]
#  2   Group/Semi Final/Final    27 non-null     object
#  3   Match Between             27 non-null     object
#  4   Venue                     27 non-null     object
#  5   Winning Team Score        27 non-null     object
#  6   Losing Team Score         27 non-null     object
#  7   Winner Team               27 non-null     object
#  8   Result                    27 non-null     object
#  9   Player Of The Match       27 non-null     object
#  10  Team1                     27 non-null     object
#  11  Team2                     27 non-null     object
#  12  Losing Team               27 non-null     object
# ...

# %%
wc_2007.groupby('Winner Team')['Winning Team Runs'].sum().reset_index()
# Out:
#     Winner Team  Winning Team Runs
# 0     Australia                362
# 1    Bangladesh                165
# 2       England                188
# 3         India                857
# 4            NO                  0
# 5   New Zealand                428
# 6      Pakistan                813
# 7  South Africa                666
# 8     Sri Lanka                575
# 9      Zimbabwe                139

# %%
wc_2007.groupby('Losing Team')['Losing Team Runs'].sum().reset_index()
# Out:
#      Losing Team  Losing Team Runs
# 0      Australia               475
# 1     Bangladesh               490
# 2        England               629
# 3          India               180
# 4          Kenya               161
# 5             NO                 0
# 6    New Zealand               460
# 7       Pakistan               293
# 8       Scotland               120
# 9   South Africa               116
# 10     Sri Lanka               257
# 11   West Indies               369
# 12      Zimbabwe               138

# %%
wc_2007_matches = wc_2007[(wc_2007['Group/Semi Final/Final'] != '1st Semi Final') & (wc_2007['Group/Semi Final/Final'] != '2nd Semi Final') & (wc_2007['Group/Semi Final/Final'] != 'Final')]

# %%
wc_2007_runs_in_loss = wc_2007_matches.groupby('Losing Team')['Losing Team Runs'].sum().reset_index()

# %%
wc_2007_runs_overs_in_loss = wc_2007_matches.groupby('Losing Team').agg({'Losing Team Runs': 'sum', 'Losing Team Over Played': 'sum'}).reset_index()

# %%
wc_2007_runs_overs_in_wins = wc_2007_matches.groupby('Winner Team').agg({'Winning Team Runs': 'sum', 'Winning Team Over Played': 'sum'}).reset_index()

# %%
wc_2007
# Out:
#     Match No       Date Group/Semi Final/Final                Match Between  \
# 0          1 2007-11-09                Group A  South Africa vs West Indies
# 1          2 2007-12-09                Group C         Kenya vs New Zealand
# 2          3 2007-12-09                Group D         Pakistan vs Scotland
# 3          4 2007-12-09                Group B        Australia vs Zimbabwe
# 4          5 2007-09-13                Group A    Bangladesh vs West Indies
# 5          6 2007-09-13                Group B          England vs Zimbabwe
# 6          7 2007-09-13                Group D            India vs Scotland
# 7          8 2007-09-14                Group C           Kenya vs Sri Lanka
# 8          9 2007-09-14                Group B         Australia vs England
# 9         10 2007-09-14                Group D            India vs Pakistan
# 10        11 2007-09-15                Group C     New Zealand vs Sri Lanka
# ...

# %%
wc_2007['Winning Team NRR'] = (wc_2007['Winning Team Runs']/ wc_2007['Winning Team Over Played'])- (wc_2007['Losing Team Runs']/ wc_2007['Losing Team Over Played'])

# %%
wc_2007['Losing Team NRR'] = (wc_2007['Losing Team Runs']/ wc_2007['Losing Team Over Played'])- (wc_2007['Winning Team Runs']/ wc_2007['Winning Team Over Played'])

# %%
wc_2007
# Out:
#     Match No       Date Group/Semi Final/Final                Match Between  \
# 0          1 2007-11-09                Group A  South Africa vs West Indies
# 1          2 2007-12-09                Group C         Kenya vs New Zealand
# 2          3 2007-12-09                Group D         Pakistan vs Scotland
# 3          4 2007-12-09                Group B        Australia vs Zimbabwe
# 4          5 2007-09-13                Group A    Bangladesh vs West Indies
# 5          6 2007-09-13                Group B          England vs Zimbabwe
# 6          7 2007-09-13                Group D            India vs Scotland
# 7          8 2007-09-14                Group C           Kenya vs Sri Lanka
# 8          9 2007-09-14                Group B         Australia vs England
# 9         10 2007-09-14                Group D            India vs Pakistan
# 10        11 2007-09-15                Group C     New Zealand vs Sri Lanka
# ...

# %% [markdown]
# filling missing value for wininfg and losing team nrr

# %%
wc_2007.fillna(0,inplace=True)

# %%
winning_nrr = wc_2007.groupby('Winner Team')['Winning Team NRR'].sum().reset_index()
winning_nrr
# Out:
#     Winner Team  Winning Team NRR
# 0     Australia         10.431335
# 1    Bangladesh          0.966667
# 2       England          2.500000
# 3         India          3.474352
# 4            NO          0.000000
# 5   New Zealand          6.325758
# 6      Pakistan          5.485401
# 7  South Africa          3.707026
# 8     Sri Lanka         11.316657
# 9      Zimbabwe          0.228205

# %%
losing_nrr = wc_2007.groupby('Losing Team')['Losing Team NRR'].sum().reset_index()

# %%
total_rnn = pd.merge(winning_nrr, losing_nrr, how='left', left_on='Winner Team', right_on='Losing Team')

# %%
total_rnn['Net Run Rate'] = total_rnn['Winning Team NRR'] + total_rnn['Losing Team NRR']

# %%
total_rnn
# Out:
#     Winner Team  Winning Team NRR   Losing Team  Losing Team NRR  Net Run Rate
# 0     Australia         10.431335     Australia        -1.416949      9.014386
# 1    Bangladesh          0.966667    Bangladesh        -5.665656     -4.698990
# 2       England          2.500000       England        -4.729310     -2.229310
# 3         India          3.474352         India        -0.500000      2.974352
# 4            NO          0.000000            NO         0.000000      0.000000
# 5   New Zealand          6.325758   New Zealand        -2.299278      4.026479
# 6      Pakistan          5.485401      Pakistan         0.025648      5.511049
# 7  South Africa          3.707026  South Africa        -1.850000      1.857026
# 8     Sri Lanka         11.316657     Sri Lanka        -6.416839      4.899818
# 9      Zimbabwe          0.228205      Zimbabwe        -2.500000     -2.271795

# %%
wc_2007['Group/Semi Final/Final'].value_counts()
# Out:
# Group E           6
# Group F           6
# Group A           3
# Group C           3
# Group D           3
# Group B           3
# 1st Semi Final    1
# 2nd Semi Final    1
# Final             1
# Name: Group/Semi Final/Final, dtype: int64

# %%
wc_2007['Winner Team'].value_counts()
# Out:
# Pakistan        5
# India           5
# South Africa    4
# New Zealand     3
# Sri Lanka       3
# Australia       3
# Zimbabwe        1
# Bangladesh      1
# England         1
# NO              1
# Name: Winner Team, dtype: int64

# %%
wc_2007_groupA_tabel = wc_2007[wc_2007['Group/Semi Final/Final']=='Group A']
wc_2007_groupB_tabel = wc_2007[wc_2007['Group/Semi Final/Final']=='Group B']
wc_2007_groupC_tabel = wc_2007[wc_2007['Group/Semi Final/Final']=='Group C']
wc_2007_groupD_tabel = wc_2007[wc_2007['Group/Semi Final/Final']=='Group D']
wc_2007_groupE_tabel = wc_2007[wc_2007['Group/Semi Final/Final']=='Group E']
wc_2007_groupF_tabel = wc_2007[wc_2007['Group/Semi Final/Final']=='Group F']
wc_2007_semi1_tabel = wc_2007[wc_2007['Group/Semi Final/Final']=='1st Semi Final']
wc_2007_semi2_tabel = wc_2007[wc_2007['Group/Semi Final/Final']=='2nd Semi Final']
wc_2007_final_table = wc_2007[wc_2007['Group/Semi Final/Final']=='Final']

# %% [markdown]
# Group A

# %%
wc_2007_groupA_tabel
# Out:
#     Match No       Date Group/Semi Final/Final                Match Between  \
# 0          1 2007-11-09                Group A  South Africa vs West Indies
# 4          5 2007-09-13                Group A    Bangladesh vs West Indies
# 11        12 2007-09-15                Group A   South Africa vs Bangladesh
#
#                                   Venue Winning Team Score Losing Team Score  \
# 0   The Wanderers Stadium, Johannesburg  208/2(17.4 overs)   205/6(20 overs)
# 4   The Wanderers Stadium, Johannesburg    165/4(18 overs)   164/8(20 overs)
# 11                  Newlands, Cape Town  146/3(18.5 overs)   144(19.3 overs)
#
#      Winner Team                         Result Player Of The Match  \
# 0   South Africa  South Africa won by 8 wickets         Chris Gayle
# 4     Bangladesh    Bangladesh won by 6 wickets   Mohammad Ashraful
# 11  South Africa  South Africa won by 7 wickets        Morne Morkel
#
#            Team1        Team2  Losing Team  Winning Team Runs  \
# ...

# %%
unique_teamsA = pd.unique(wc_2007_groupA_tabel[['Winner Team','Losing Team']].values.ravel('K'))

# %%
unique_teamsA
# Out:
# array(['South Africa', 'Bangladesh', 'West Indies'], dtype=object)

# %%
win_countsA = pd.DataFrame(wc_2007_groupA_tabel['Winner Team'].value_counts()).reset_index()
win_countsA = win_countsA.rename(columns={"index":"Teams", "Winner Team": "Won"})
win_countsA
# Out:
#           Teams  Won
# 0  South Africa    2
# 1    Bangladesh    1

# %%
groupA_point_table = pd.DataFrame({"Teams":unique_teamsA, "Matches": len(unique_teamsA)-1})

# %%
groupA_point_table
# Out:
#           Teams  Matches
# 0  South Africa        2
# 1    Bangladesh        2
# 2   West Indies        2

# %%
groupA_point_table = pd.merge(groupA_point_table, win_countsA, how="left", left_on='Teams', right_on='Teams')

# %%
groupA_point_table.fillna(0,inplace=True)

# %%
groupA_point_table
# Out:
#           Teams  Matches  Won
# 0  South Africa        2  2.0
# 1    Bangladesh        2  1.0
# 2   West Indies        2  0.0

# %%
groupA_point_table['Loss'] = groupA_point_table['Matches'] - groupA_point_table['Won']

# %%
groupA_point_table
# Out:
#           Teams  Matches  Won  Loss
# 0  South Africa        2  2.0   0.0
# 1    Bangladesh        2  1.0   1.0
# 2   West Indies        2  0.0   2.0

# %%
groupA_point_table['Point'] = 2*groupA_point_table['Won']
groupA_point_table
# Out:
#           Teams  Matches  Won  Loss  Point
# 0  South Africa        2  2.0   0.0    4.0
# 1    Bangladesh        2  1.0   1.0    2.0
# 2   West Indies        2  0.0   2.0    0.0

# %%
nrr = pd.merge(wc_2007_groupA_tabel.groupby('Winner Team')['Winning Team NRR'].sum().reset_index(),wc_2007_groupA_tabel.groupby('Losing Team')['Losing Team NRR'].sum().reset_index(), how='outer', left_on='Winner Team', right_on='Losing Team')

# %%
nrr['Teams'] = nrr['Winner Team'].combine_first(nrr['Losing Team'])

# %%
nrr.drop(columns={'Winner Team', 'Losing Team'}, inplace=True)
nrr.fillna(0, inplace=True)

# %%
nrr['NRR'] = nrr['Winning Team NRR'] + nrr['Losing Team NRR']

# %%
nrr.drop(columns={'Winning Team NRR', 'Losing Team NRR'}, inplace=True)

# %%
nrr = nrr.sort_values('NRR', ascending=False).reset_index(drop=True)

# %%
nrr
# Out:
#           Teams       NRR
# 0  South Africa  2.134775
# 1    Bangladesh  0.535915
# 2   West Indies -2.670690

# %%
groupA_point_table = pd.merge(groupA_point_table, nrr, on='Teams', how='left')
groupA_point_table
# Out:
#           Teams  Matches  Won  Loss  Point       NRR
# 0  South Africa        2  2.0   0.0    4.0  2.134775
# 1    Bangladesh        2  1.0   1.0    2.0  0.535915
# 2   West Indies        2  0.0   2.0    0.0 -2.670690

# %% [markdown]
# Group D, im handling tie case manually (Special case)

# %%
wc_2007_groupD_tabel
# Out:
#    Match No       Date Group/Semi Final/Final         Match Between  \
# 2         3 2007-12-09                Group D  Pakistan vs Scotland
# 6         7 2007-09-13                Group D     India vs Scotland
# 9        10 2007-09-14                Group D     India vs Pakistan
#
#                Venue Winning Team Score Losing Team Score Winner Team  \
# 2  Kingsmead, Durban    171/9(20 overs)   120(19.5 overs)    Pakistan
# 6  Kingsmead, Durban                 NO                NO          NO
# 9  Kingsmead, Durban    141/9(20 overs)   141/7(20 overs)       India
#
#                                 Result Player Of The Match     Team1  \
# 2              Pakistan won by 51 runs       Shahid Afridi  Pakistan
# 6    No result (abandoned with a toss)                  NO     India
# 9  Match tied (India won the bowl-out)       Mohammad Asif     India
#
#       Team2 Losing Team  Winning Team Runs  Winning Team Over Played  \
# ...

# %%
unique_teamsD = pd.unique(wc_2007_groupD_tabel[['Winner Team','Losing Team']].values.ravel('K'))
unique_teamsD
# Out:
# array(['Pakistan', 'NO', 'India', 'Scotland'], dtype=object)

# %%
win_countsD = pd.DataFrame(wc_2007_groupD_tabel['Winner Team'].value_counts()).reset_index()
win_countsD = win_countsD.rename(columns={"index":"Teams", "Winner Team": "Won"})
win_counts = win_countsD[win_countsD['Teams'] != 'NO'].reset_index().drop(columns='index')
win_counts
# Out:
#       Teams  Won
# 0  Pakistan    1
# 1     India    1

# %%
groupD_point_table = pd.DataFrame({"Teams":unique_teamsD, "Matches":2})
groupD_point_table = groupD_point_table[groupD_point_table['Teams'] != 'NO'].reset_index().drop(columns={'index'})

# %%
groupD_point_table
# Out:
#       Teams  Matches
# 0  Pakistan        2
# 1     India        2
# 2  Scotland        2

# %%
groupD_point_table = pd.merge(groupD_point_table, win_countsD, how='left', left_on='Teams', right_on='Teams')

# %%
groupD_point_table.fillna(0,inplace=True)

# %%
groupD_point_table
# Out:
#       Teams  Matches  Won
# 0  Pakistan        2  1.0
# 1     India        2  1.0
# 2  Scotland        2  0.0

# %%
groupD_point_table['Tie'] = 1

# %%
groupD_point_table.loc[groupD_point_table['Teams']=='Pakistan','Tie'] = 0

# %%
groupD_point_table['Loss'] = groupD_point_table['Matches'] - groupD_point_table['Won'] - groupD_point_table['Tie']

# %%
groupD_point_table['Points'] = 2*groupD_point_table['Won'] + groupD_point_table['Tie']

# %%
groupD_point_table = groupD_point_table.sort_values(by='Points', ascending=False).reset_index(drop=True)

# %%
groupD_point_table = groupD_point_table[['Teams', 'Matches', 'Won', 'Loss', 'Tie', 'Points']]

# %%
groupD_point_table
# Out:
#       Teams  Matches  Won  Loss  Tie  Points
# 0     India        2  1.0   0.0    1     3.0
# 1  Pakistan        2  1.0   1.0    0     2.0
# 2  Scotland        2  0.0   1.0    1     1.0

# %%
nrrD = pd.merge(wc_2007_groupD_tabel.groupby('Winner Team')['Winning Team NRR'].sum().reset_index(),wc_2007_groupD_tabel.groupby('Losing Team')['Losing Team NRR'].sum().reset_index(), how='outer', left_on='Winner Team', right_on='Losing Team')

# %%
nrrD['Teams'] = nrrD['Winner Team'].combine_first(nrrD['Losing Team'])

# %%
nrrD.drop(columns={'Winner Team', 'Losing Team'}, inplace=True)
nrrD.fillna(0, inplace=True)

# %%
nrrD = nrrD[nrrD['Teams']!='NO']

# %%
nrrD
# Out:
#    Winning Team NRR  Losing Team NRR     Teams
# 0          0.000000         0.000000     India
# 2          2.396154         0.000000  Pakistan
# 3          0.000000        -2.396154  Scotland

# %%
nrrD['NRR'] = nrrD['Winning Team NRR'] + nrrD['Losing Team NRR']

# %%
nrrD.drop(columns={'Winning Team NRR', 'Losing Team NRR'}, inplace=True)

# %%
groupD_point_table = pd.merge(groupD_point_table, nrrD, on='Teams', how='left')
groupD_point_table
# Out:
#       Teams  Matches  Won  Loss  Tie  Points       NRR
# 0     India        2  1.0   0.0    1     3.0  0.000000
# 1  Pakistan        2  1.0   1.0    0     2.0  2.396154
# 2  Scotland        2  0.0   1.0    1     1.0 -2.396154

# %% [markdown]
# Group B

# %%
wc_2007_groupB_tabel
# Out:
#    Match No       Date Group/Semi Final/Final          Match Between  \
# 3         4 2007-12-09                Group B  Australia vs Zimbabwe
# 5         6 2007-09-13                Group B    England vs Zimbabwe
# 8         9 2007-09-14                Group B   Australia vs England
#
#                  Venue Winning Team Score Losing Team Score Winner Team  \
# 3  Newlands, Cape Town  139/5(19.5 overs)   138/9(20 overs)    Zimbabwe
# 5  Newlands, Cape Town    188/9(20 overs)   138/7(20 overs)     England
# 8  Newlands, Cape Town  136/2(14.5 overs)     135(20 overs)   Australia
#
#                        Result Player Of The Match      Team1     Team2  \
# 3   Zimbabwe won by 5 wickets      Brendan Taylor  Australia  Zimbabwe
# 5      England won by 50 runs     Kevin Pietersen    England  Zimbabwe
# 8  Australia won by 8 wickets      Nathan Bracken  Australia   England
#
#   Losing Team  Winning Team Runs  Winning Team Over Played  Losing Team Runs  \
# ...

# %%
unique_teamsB = pd.unique(wc_2007_groupB_tabel[['Winner Team', 'Losing Team']].values.ravel('K'))

# %%
unique_teamsB
# Out:
# array(['Zimbabwe', 'England', 'Australia'], dtype=object)

# %%
win_countsB = pd.DataFrame(wc_2007_groupB_tabel['Winner Team'].value_counts()).reset_index()
win_countsB = win_countsB.rename(columns={"index":"Teams", "Winner Team": "Won"})
win_countsB
# Out:
#        Teams  Won
# 0   Zimbabwe    1
# 1    England    1
# 2  Australia    1

# %%
groupB_point_table = pd.DataFrame({"Teams":unique_teamsB, "Matches": len(unique_teamsB)-1})

# %%
groupB_point_table
# Out:
#        Teams  Matches
# 0   Zimbabwe        2
# 1    England        2
# 2  Australia        2

# %%
groupB_point_table = pd.merge(groupB_point_table, win_countsB, how="left", left_on='Teams', right_on='Teams')

# %%
groupB_point_table['Loss'] = groupB_point_table['Matches'] - groupB_point_table['Won']

# %%
groupB_point_table
# Out:
#        Teams  Matches  Won  Loss
# 0   Zimbabwe        2    1     1
# 1    England        2    1     1
# 2  Australia        2    1     1

# %%
groupB_point_table['Tie'] = groupB_point_table['Matches'] - groupB_point_table['Won']- groupB_point_table['Loss']

# %%
groupB_point_table['Point'] = 2*groupB_point_table['Won'] + groupB_point_table['Tie']

# %%
groupB_point_table
# Out:
#        Teams  Matches  Won  Loss  Tie  Point
# 0   Zimbabwe        2    1     1    0      2
# 1    England        2    1     1    0      2
# 2  Australia        2    1     1    0      2

# %%
nrrB = pd.merge(wc_2007_groupB_tabel.groupby('Winner Team')['Winning Team NRR'].sum().reset_index(),wc_2007_groupB_tabel.groupby('Losing Team')['Losing Team NRR'].sum().reset_index(), how='outer', left_on='Winner Team', right_on='Losing Team')

# %%
nrrB
# Out:
#   Winner Team  Winning Team NRR Losing Team  Losing Team NRR
# 0   Australia          2.629310   Australia        -0.228205
# 1     England          2.500000     England        -2.629310
# 2    Zimbabwe          0.228205    Zimbabwe        -2.500000

# %%
nrrB['Teams'] = nrrB['Winner Team'].combine_first(nrrB['Losing Team'])

# %%
nrrB.drop(columns={'Winner Team', 'Losing Team'}, inplace=True)

# %%
nrrB['NRR'] = nrrB['Winning Team NRR'] + nrrB['Losing Team NRR']

# %%
nrrB.drop(columns={'Winning Team NRR', 'Losing Team NRR'}, inplace=True)

# %%
nrrB
# Out:
#        Teams       NRR
# 0  Australia  2.401105
# 1    England -0.129310
# 2   Zimbabwe -2.271795

# %%
groupB_point_table = pd.merge(groupB_point_table, nrrB, on='Teams', how='left')

# %%
groupB_point_table = groupB_point_table.sort_values('NRR', ascending=False).reset_index(drop=True)

# %%
groupB_point_table
# Out:
#        Teams  Matches  Won  Loss  Tie  Point       NRR
# 0  Australia        2    1     1    0      2  2.401105
# 1    England        2    1     1    0      2 -0.129310
# 2   Zimbabwe        2    1     1    0      2 -2.271795

# %% [markdown]
# Group C

# %%
wc_2007_groupC_tabel
# Out:
#     Match No       Date Group/Semi Final/Final             Match Between  \
# 1          2 2007-12-09                Group C      Kenya vs New Zealand
# 7          8 2007-09-14                Group C        Kenya vs Sri Lanka
# 10        11 2007-09-15                Group C  New Zealand vs Sri Lanka
#
#                                   Venue Winning Team Score Losing Team Score  \
# 1                     Kingsmead, Durban    74/1(7.4 overs)    73(16.5 overs)
# 7   The Wanderers Stadium, Johannesburg    260/6(20 overs)    88(19.3 overs)
# 10  The Wanderers Stadium, Johannesburg  168/3(18.5 overs)   164/7(20 overs)
#
#     Winner Team                        Result Player Of The Match  \
# 1   New Zealand  New Zealand won by 9 wickets      Mark Gillespie
# 7     Sri Lanka     Sri Lanka won by 172 runs   Sanath Jayasuriya
# 10    Sri Lanka    Sri Lanka won by 7 wickets   Sanath Jayasuriya
#
#           Team1        Team2  Losing Team  Winning Team Runs  \
# ...

# %%
unique_teamsC = pd.unique(wc_2007_groupC_tabel[['Winner Team', 'Losing Team']].values.ravel('K'))

# %%
unique_teamsC
# Out:
# array(['New Zealand', 'Sri Lanka', 'Kenya'], dtype=object)

# %%
win_countsC = pd.DataFrame(wc_2007_groupC_tabel['Winner Team'].value_counts()).reset_index()
win_countsC = win_countsC.rename(columns={'index':'Teams', "Winner Team": "Won"})
win_countsC
# Out:
#          Teams  Won
# 0    Sri Lanka    2
# 1  New Zealand    1

# %%
groupC_point_table = pd.DataFrame({"Teams":unique_teamsC, "Matches": len(unique_teamsC)-1})

# %%
groupC_point_table
# Out:
#          Teams  Matches
# 0  New Zealand        2
# 1    Sri Lanka        2
# 2        Kenya        2

# %%
groupC_point_table = pd.merge(groupC_point_table, win_countsC, how="left", left_on='Teams', right_on='Teams')

# %%
groupC_point_table
# Out:
#          Teams  Matches  Won
# 0  New Zealand        2  1.0
# 1    Sri Lanka        2  2.0
# 2        Kenya        2  NaN

# %%
groupC_point_table.fillna(0,inplace=True)

# %%
groupC_point_table['Loss'] = groupC_point_table['Matches'] - groupC_point_table['Won']

# %%
groupC_point_table['Tie'] = groupC_point_table['Matches'] - groupC_point_table['Won']- groupC_point_table['Loss']

# %%
groupC_point_table['Points'] = 2*groupC_point_table['Won'] + groupC_point_table['Tie']

# %%
groupC_point_table = groupC_point_table.sort_values(by='Points', ascending=False).reset_index(drop=True)

# %%
groupC_point_table
# Out:
#          Teams  Matches  Won  Loss  Tie  Points
# 0    Sri Lanka        2  2.0   0.0  0.0     4.0
# 1  New Zealand        2  1.0   1.0  0.0     2.0
# 2        Kenya        2  0.0   2.0  0.0     0.0

# %%
nrrC = pd.merge(wc_2007_groupC_tabel.groupby('Winner Team')['Winning Team NRR'].sum().reset_index(),wc_2007_groupC_tabel.groupby('Losing Team')['Losing Team NRR'].sum().reset_index(), how='outer', left_on='Winner Team', right_on='Losing Team')

# %%
nrrC['Teams'] = nrrC['Winner Team'].combine_first(nrrC['Losing Team'])

# %%
nrrC.drop(columns={'Winner Team', 'Losing Team'}, inplace=True)
nrrC.fillna(0, inplace=True)

# %%
nrrC['NRR'] = nrrC['Winning Team NRR'] + nrrC['Losing Team NRR']

# %%
nrrC
# Out:
#    Winning Team NRR  Losing Team NRR        Teams        NRR
# 0          5.575758        -0.881081  New Zealand   4.694676
# 1          9.321496         0.000000    Sri Lanka   9.321496
# 2          0.000000       -14.016172        Kenya -14.016172

# %%
nrrC.drop(columns={'Winning Team NRR', 'Losing Team NRR'}, inplace=True)

# %%
nrrC
# Out:
#          Teams        NRR
# 0  New Zealand   4.694676
# 1    Sri Lanka   9.321496
# 2        Kenya -14.016172

# %%
groupC_point_table = pd.merge(groupC_point_table, nrrC, on='Teams', how='left')
groupC_point_table
# Out:
#          Teams  Matches  Won  Loss  Tie  Points        NRR
# 0    Sri Lanka        2  2.0   0.0  0.0     4.0   9.321496
# 1  New Zealand        2  1.0   1.0  0.0     2.0   4.694676
# 2        Kenya        2  0.0   2.0  0.0     0.0 -14.016172

# %% [markdown]
# Group E

# %%
wc_2007_groupE_tabel
# Out:
#     Match No       Date Group/Semi Final/Final                Match Between  \
# 12        13 2007-09-16                Group E         India vs New Zealand
# 14        15 2007-09-16                Group E      South Africa vs England
# 16        17 2007-09-18                Group E       England vs New Zealand
# 19        20 2007-09-19                Group E  South Africa vs New Zealand
# 20        21 2007-09-19                Group E             England vs India
# 23        24 2007-09-20                Group E        South Africa vs India
#
#                                   Venue Winning Team Score Losing Team Score  \
# 12  The Wanderers Stadium, Johannesburg      190(20 overs)   180/9(20 overs)
# 14                  Newlands, Cape Town    154/8(20 overs)   135/7(20 overs)
# 16                    Kingsmead, Durban    164/9(20 overs)   159/8(20 overs)
# 19                    Kingsmead, Durban  158/4(19.1 overs)   153/8(20 overs)
# ...

# %%
unique_teamsE = pd.unique(wc_2007_groupE_tabel[['Winner Team', 'Losing Team']].values.ravel('K'))

# %%
unique_teamsE
# Out:
# array(['New Zealand', 'South Africa', 'India', 'England'], dtype=object)

# %%
win_countsE = pd.DataFrame(wc_2007_groupE_tabel['Winner Team'].value_counts()).reset_index()
win_countsE = win_countsE.rename(columns={'index':'Teams', "Winner Team": "Won"})
win_countsE
# Out:
#           Teams  Won
# 0   New Zealand    2
# 1  South Africa    2
# 2         India    2

# %%
groupE_point_table = pd.DataFrame({"Teams":unique_teamsE, "Matches": len(unique_teamsE)-1})

# %%
groupE_point_table
# Out:
#           Teams  Matches
# 0   New Zealand        3
# 1  South Africa        3
# 2         India        3
# 3       England        3

# %%
groupE_point_table = pd.merge(groupE_point_table, win_countsE, how="left", left_on='Teams', right_on='Teams')

# %%
groupE_point_table
# Out:
#           Teams  Matches  Won
# 0   New Zealand        3  2.0
# 1  South Africa        3  2.0
# 2         India        3  2.0
# 3       England        3  NaN

# %%
groupE_point_table.fillna(0,inplace=True)

# %%
groupE_point_table['Loss'] = groupE_point_table['Matches'] - groupE_point_table['Won']

# %%
groupE_point_table['Tie'] = groupE_point_table['Matches'] - groupE_point_table['Won']- groupE_point_table['Loss']

# %%
groupE_point_table['Points'] = 2*groupE_point_table['Won'] + groupE_point_table['Tie']

# %%
groupE_point_table = groupE_point_table.sort_values(by='Points', ascending=False).reset_index(drop=True)

# %%
groupE_point_table
# Out:
#           Teams  Matches  Won  Loss  Tie  Points
# 0   New Zealand        3  2.0   1.0  0.0     4.0
# 1  South Africa        3  2.0   1.0  0.0     4.0
# 2         India        3  2.0   1.0  0.0     4.0
# 3       England        3  0.0   3.0  0.0     0.0

# %%
nrrE = pd.merge(wc_2007_groupE_tabel.groupby('Winner Team')['Winning Team NRR'].sum().reset_index(),wc_2007_groupE_tabel.groupby('Losing Team')['Losing Team NRR'].sum().reset_index(), how='outer', left_on='Winner Team', right_on='Losing Team')

# %%
nrrE['Teams'] = nrrE['Winner Team'].combine_first(nrrE['Losing Team'])

# %%
nrrE.drop(columns={'Winner Team', 'Losing Team'}, inplace=True)

# %%
nrrE.fillna(0, inplace=True)

# %%
nrrE['NRR'] = nrrE['Winning Team NRR'] + nrrE['Losing Team NRR']

# %%
nrrE.drop(columns={'Winning Team NRR', 'Losing Team NRR'}, inplace=True)

# %%
groupE_point_table = pd.merge(groupE_point_table, nrrE, on='Teams', how='left')

# %%
groupE_point_table
# Out:
#           Teams  Matches  Won  Loss  Tie  Points       NRR
# 0   New Zealand        3  2.0   1.0  0.0     4.0  0.127749
# 1  South Africa        3  2.0   1.0  0.0     4.0 -0.277749
# 2         India        3  2.0   1.0  0.0     4.0  2.250000
# 3       England        3  0.0   3.0  0.0     0.0 -2.100000

# %%
groupE_point_table = groupE_point_table.sort_values('NRR', ascending=False).reset_index(drop=True)

# %%
groupE_point_table
# Out:
#           Teams  Matches  Won  Loss  Tie  Points       NRR
# 0         India        3  2.0   1.0  0.0     4.0  2.250000
# 1   New Zealand        3  2.0   1.0  0.0     4.0  0.127749
# 2  South Africa        3  2.0   1.0  0.0     4.0 -0.277749
# 3       England        3  0.0   3.0  0.0     0.0 -2.100000

# %% [markdown]
# Group F

# %%
wc_2007_groupF_tabel
# Out:
#     Match No       Date Group/Semi Final/Final            Match Between  \
# 13        14 2007-09-16                Group F  Australia vs Bangladesh
# 15        16 2007-09-17                Group F    Pakistan vs Sri Lanka
# 17        18 2007-09-18                Group F    Australia vs Pakistan
# 18        19 2007-09-18                Group F  Bangladesh vs Sri Lanka
# 21        22 2007-09-20                Group F   Australia vs Sri Lanka
# 22        23 2007-09-20                Group F   Bangladesh vs Pakistan
#
#                                   Venue Winning Team Score Losing Team Score  \
# 13                  Newlands, Cape Town  124/1(13.5 overs)   123/8(20 overs)
# 15  The Wanderers Stadium, Johannesburg    189/6(20 overs)   156/9(20 overs)
# 17  The Wanderers Stadium, Johannesburg  165/4(19.1 overs)   164/7(20 overs)
# 18  The Wanderers Stadium, Johannesburg    147/5(20 overs)    83(15.5 overs)
# 21                  Newlands, Cape Town  102/0(10.2 overs)   101(19.3 overs)
# ...

# %%
unique_teamsF = pd.unique(wc_2007_groupF_tabel[['Winner Team','Losing Team']].values.ravel('K'))

# %%
unique_teamsF
# Out:
# array(['Australia', 'Pakistan', 'Sri Lanka', 'Bangladesh'], dtype=object)

# %%
win_countsF = pd.DataFrame(wc_2007_groupF_tabel['Winner Team'].value_counts()).reset_index()
win_countsF = win_countsF.rename(columns={"index":"Teams", "Winner Team": "Won"})
win_countsF
# Out:
#        Teams  Won
# 0   Pakistan    3
# 1  Australia    2
# 2  Sri Lanka    1

# %%
groupF_point_table = pd.DataFrame({"Teams":unique_teamsF, "Matches": len(unique_teamsF)-1})

# %%
groupF_point_table
# Out:
#         Teams  Matches
# 0   Australia        3
# 1    Pakistan        3
# 2   Sri Lanka        3
# 3  Bangladesh        3

# %%
groupF_point_table = pd.merge(groupF_point_table, win_countsF, how="left", left_on='Teams', right_on='Teams')

# %%
groupF_point_table.fillna(0,inplace=True)

# %%
groupF_point_table
# Out:
#         Teams  Matches  Won
# 0   Australia        3  2.0
# 1    Pakistan        3  3.0
# 2   Sri Lanka        3  1.0
# 3  Bangladesh        3  0.0

# %%
groupF_point_table['Loss'] = groupF_point_table['Matches'] - groupF_point_table['Won']

# %%
groupF_point_table['Point'] = 2*groupF_point_table['Won']
groupF_point_table
# Out:
#         Teams  Matches  Won  Loss  Point
# 0   Australia        3  2.0   1.0    4.0
# 1    Pakistan        3  3.0   0.0    6.0
# 2   Sri Lanka        3  1.0   2.0    2.0
# 3  Bangladesh        3  0.0   3.0    0.0

# %%
nrrF = pd.merge(wc_2007_groupF_tabel.groupby('Winner Team')['Winning Team NRR'].sum().reset_index(),wc_2007_groupF_tabel.groupby('Losing Team')['Losing Team NRR'].sum().reset_index(), how='outer', left_on='Winner Team', right_on='Losing Team')

# %%
nrrF['Teams'] = nrrF['Winner Team'].combine_first(nrrF['Losing Team'])

# %%
nrrF.drop(columns={'Winner Team', 'Losing Team'}, inplace=True)
nrrF.fillna(0, inplace=True)

# %%
nrrF['NRR'] = nrrF['Winning Team NRR'] + nrrF['Losing Team NRR']

# %%
nrrF.drop(columns={'Winning Team NRR', 'Losing Team NRR'}, inplace=True)

# %%
groupF_point_table = pd.merge(groupF_point_table, nrrF, on='Teams', how='left')
groupF_point_table
# Out:
#         Teams  Matches  Won  Loss  Point       NRR
# 0   Australia        3  2.0   1.0    4.0  7.363281
# 1    Pakistan        3  3.0   0.0    6.0  2.293301
# 2   Sri Lanka        3  1.0   2.0    2.0 -4.421678
# 3  Bangladesh        3  0.0   3.0    0.0 -5.234904

# %%
groupF_point_table = groupF_point_table.sort_values('Point', ascending=False).reset_index(drop=True)

# %%
groupF_point_table
# Out:
#         Teams  Matches  Won  Loss  Point       NRR
# 0    Pakistan        3  3.0   0.0    6.0  2.293301
# 1   Australia        3  2.0   1.0    4.0  7.363281
# 2   Sri Lanka        3  1.0   2.0    2.0 -4.421678
# 3  Bangladesh        3  0.0   3.0    0.0 -5.234904

# %% [markdown]
# Semi-Final 1

# %%
wc_2007_semi1_tabel
# Out:
#     Match No       Date Group/Semi Final/Final            Match Between  \
# 24        25 2007-09-22         1st Semi Final  New Zealand vs Pakistan
#
#                   Venue Winning Team Score Losing Team Score Winner Team  \
# 24  Newlands, Cape Town  147/4(18.5 overs)   143/8(20 overs)    Pakistan
#
#                        Result Player Of The Match        Team1     Team2  \
# 24  Pakistan won by 6 wickets            Umar Gul  New Zealand  Pakistan
#
#     Losing Team  Winning Team Runs  Winning Team Over Played  \
# 24  New Zealand                147                      18.5
#
#     Losing Team Runs  Losing Team Over Played  Winning Team NRR  \
# 24               143                     20.0          0.795946
#
#     Losing Team NRR
# 24        -0.795946

# %% [markdown]
# Semi-Final 2

# %%
wc_2007_semi2_tabel
# Out:
#     Match No       Date Group/Semi Final/Final       Match Between  \
# 25        26 2007-09-22         2nd Semi Final  Australia vs India
#
#                 Venue Winning Team Score Losing Team Score Winner Team  \
# 25  Kingsmead, Durban    188/5(20 overs)   173/7(20 overs)       India
#
#                   Result Player Of The Match      Team1  Team2 Losing Team  \
# 25  India won by 15 runs        Yuvraj Singh  Australia  India   Australia
#
#     Winning Team Runs  Winning Team Over Played  Losing Team Runs  \
# 25                188                      20.0               173
#
#     Losing Team Over Played  Winning Team NRR  Losing Team NRR
# 25                     20.0              0.75            -0.75

# %% [markdown]
# Final

# %%
wc_2007_final_table
# Out:
#     Match No       Date Group/Semi Final/Final      Match Between  \
# 26        27 2007-09-24                  Final  India vs Pakistan
#
#                                   Venue Winning Team Score Losing Team Score  \
# 26  The Wanderers Stadium, Johannesburg    157/5(20 overs)   152(19.3 overs)
#
#    Winner Team               Result Player Of The Match  Team1     Team2  \
# 26       India  India won by 5 runs        Irfan Pathan  India  Pakistan
#
#    Losing Team  Winning Team Runs  Winning Team Over Played  Losing Team Runs  \
# 26    Pakistan                157                      20.0               152
#
#     Losing Team Over Played  Winning Team NRR  Losing Team NRR
# 26                     19.3         -0.025648         0.025648

# %% [markdown]
# # WC_2009

# %%
wc_2009
# Out:
#     Match No        Date Group/Semi Final/Final                Match Between  \
# 0          1  2009-05-06                Group B       England vs Netherlands
# 1          2  2009-06-06                Group D      New Zealand vs Scotland
# 2          3  2009-06-06                Group C     Australia vs West Indies
# 3          4  2009-06-06                Group A          Bangladesh vs India
# 4          5  2009-07-06                Group D     Scotland vs South Africa
# 5          6  2009-07-06                Group B          England vs Pakistan
# 6          7  2009-08-06                Group A        Bangladesh vs Ireland
# 7          8  2009-08-06                Group C       Australia vs Sri Lanka
# 8          9  2009-09-06                Group B      Netherlands vs Pakistan
# 9         10  2009-09-06                Group D  New Zealand vs South Africa
# 10        11  2009-10-06                Group C     Sri Lanka vs West Indies
# ...

# %%
wc_2009.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Match No                27 non-null     int64
#  1   Date                    27 non-null     object
#  2   Group/Semi Final/Final  27 non-null     object
#  3   Match Between           27 non-null     object
#  4   Venue                   27 non-null     object
#  5   Winning Team Score      27 non-null     object
#  6   Losing Team Score       27 non-null     object
#  7   Winner Team             27 non-null     object
#  8   Result                  27 non-null     object
#  9   Player Of The Match     27 non-null     object
# dtypes: int64(1), object(9)
# memory usage: 2.2+ KB

# %%
wc_2009.isna().sum()
# Out:
# Match No                  0
# Date                      0
# Group/Semi Final/Final    0
# Match Between             0
# Venue                     0
# Winning Team Score        0
# Losing Team Score         0
# Winner Team               0
# Result                    0
# Player Of The Match       0
# dtype: int64

# %%
wc_2009['Team1'], wc_2009['Team2'] = wc_2009['Match Between'].str.split(' vs ',1).str
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16648\2041792803.py:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   wc_2009['Team1'], wc_2009['Team2'] = wc_2009['Match Between'].str.split(' vs ',1).str
# C:\Users\HP\AppData\Local\Temp\ipykernel_16648\2041792803.py:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   wc_2009['Team1'], wc_2009['Team2'] = wc_2009['Match Between'].str.split(' vs ',1).str

# %%
wc_2009['Losing Team'] = np.where(wc_2009['Winner Team']==wc_2009['Team1'], wc_2009['Team2'], wc_2009['Team1'])

# %%
wc_2009['Date'] = pd.to_datetime(wc_2009['Date'])

# %%
wc_2009.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Match No                27 non-null     int64
#  1   Date                    27 non-null     datetime64[ns]
#  2   Group/Semi Final/Final  27 non-null     object
#  3   Match Between           27 non-null     object
#  4   Venue                   27 non-null     object
#  5   Winning Team Score      27 non-null     object
#  6   Losing Team Score       27 non-null     object
#  7   Winner Team             27 non-null     object
#  8   Result                  27 non-null     object
#  9   Player Of The Match     27 non-null     object
#  10  Team1                   27 non-null     object
#  11  Team2                   27 non-null     object
#  12  Losing Team             27 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(11)
# memory usage: 2.9+ KB

# %% [markdown]
# extracting runs and overs of winning team

# %%
wc_2009['Winning Team Runs'] = wc_2009['Winning Team Score'].str.extract(r'(\d+)')
wc_2009['Winning Team Over Played']=wc_2009['Winning Team Score'].str.extract(r'\((\d+(?:\.\d{1,2})?) overs\)')

# %% [markdown]
# extracting runs and overs of losing team

# %%
wc_2009['Losing Team Runs'] = wc_2009['Losing Team Score'].str.extract(r'(\d+)')
wc_2009['Losing Team Over Played']=wc_2009['Losing Team Score'].str.extract(r'\((\d+(?:\.\d{1,2})?) overs\)')

# %%
wc_2009['Winning Team Runs'] = pd.to_numeric(wc_2009['Winning Team Runs'])
wc_2009['Winning Team Over Played'] = pd.to_numeric(wc_2009['Winning Team Over Played'])
wc_2009['Losing Team Runs'] = pd.to_numeric(wc_2009['Losing Team Runs'])
wc_2009['Losing Team Over Played'] = pd.to_numeric(wc_2009['Losing Team Over Played'])

# %%
wc_2009.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Match No                  27 non-null     int64
#  1   Date                      27 non-null     datetime64[ns]
#  2   Group/Semi Final/Final    27 non-null     object
#  3   Match Between             27 non-null     object
#  4   Venue                     27 non-null     object
#  5   Winning Team Score        27 non-null     object
#  6   Losing Team Score         27 non-null     object
#  7   Winner Team               27 non-null     object
#  8   Result                    27 non-null     object
#  9   Player Of The Match       27 non-null     object
#  10  Team1                     27 non-null     object
#  11  Team2                     27 non-null     object
#  12  Losing Team               27 non-null     object
# ...

# %%
wc_2009.groupby('Winner Team')['Winning Team Runs'].sum().reset_index()
# Out:
#     Winner Team  Winning Team Runs
# 0       England                338
# 1         India                293
# 2       Ireland                138
# 3   Netherlands                163
# 4   New Zealand                288
# 5      Pakistan                721
# 6  South Africa                766
# 7     Sri Lanka                962
# 8   West Indies                410

# %%
wc_2009.groupby('Losing Team')['Losing Team Runs'].sum().reset_index()
# Out:
#      Losing Team  Losing Team Runs
# 0      Australia               328
# 1     Bangladesh               292
# 2        England               434
# 3          India               421
# 4        Ireland               482
# 5    Netherlands                93
# 6    New Zealand               336
# 7       Pakistan               268
# 8       Scotland               170
# 9   South Africa               142
# 10     Sri Lanka               139
# 11   West Indies               441

# %%
wc_2009['Group/Semi Final/Final'].value_counts()
# Out:
# Group F           6
# Group E           6
# Group B           3
# Group D           3
# Group C           3
# Group A           3
# 1st Semi Final    1
# 2nd Semi Final    1
# Final             1
# Name: Group/Semi Final/Final, dtype: int64

# %%
wc_2009_matches = wc_2009[(wc_2009['Group/Semi Final/Final'] != '1st Semi Final') & (wc_2009['Group/Semi Final/Final'] != '2nd Semi Final') & (wc_2009['Group/Semi Final/Final'] != 'Final')]

# %%
wc_2009_runs_in_loss = wc_2009_matches.groupby('Losing Team')['Losing Team Runs'].sum().reset_index()

# %%
wc_2009_runs_overs_in_loss = wc_2009_matches.groupby('Losing Team').agg({'Losing Team Runs': 'sum', 'Losing Team Over Played': 'sum'}).reset_index()

# %%
wc_2009_runs_overs_in_wins = wc_2009_matches.groupby('Winner Team').agg({'Winning Team Runs': 'sum', 'Winning Team Over Played': 'sum'}).reset_index()

# %%
wc_2009
# Out:
#     Match No       Date Group/Semi Final/Final                Match Between  \
# 0          1 2009-05-06                Group B       England vs Netherlands
# 1          2 2009-06-06                Group D      New Zealand vs Scotland
# 2          3 2009-06-06                Group C     Australia vs West Indies
# 3          4 2009-06-06                Group A          Bangladesh vs India
# 4          5 2009-07-06                Group D     Scotland vs South Africa
# 5          6 2009-07-06                Group B          England vs Pakistan
# 6          7 2009-08-06                Group A        Bangladesh vs Ireland
# 7          8 2009-08-06                Group C       Australia vs Sri Lanka
# 8          9 2009-09-06                Group B      Netherlands vs Pakistan
# 9         10 2009-09-06                Group D  New Zealand vs South Africa
# 10        11 2009-10-06                Group C     Sri Lanka vs West Indies
# ...

# %%
wc_2009['Winning Team NRR'] = (wc_2009['Winning Team Runs']/ wc_2009['Winning Team Over Played'])- (wc_2009['Losing Team Runs']/ wc_2009['Losing Team Over Played'])

# %%
wc_2009['Losing Team NRR'] = (wc_2009['Losing Team Runs']/ wc_2009['Losing Team Over Played'])- (wc_2009['Winning Team Runs']/ wc_2009['Winning Team Over Played'])

# %%
wc_2009.isna().sum()
# Out:
# Match No                    0
# Date                        0
# Group/Semi Final/Final      0
# Match Between               0
# Venue                       0
# Winning Team Score          0
# Losing Team Score           0
# Winner Team                 0
# Result                      0
# Player Of The Match         0
# Team1                       0
# Team2                       0
# Losing Team                 0
# Winning Team Runs           0
# Winning Team Over Played    0
# Losing Team Runs            0
# Losing Team Over Played     0
# Winning Team NRR            0
# Losing Team NRR             0
# dtype: int64

# %%
winning_nrr_2009 = wc_2009.groupby('Winner Team')['Winning Team NRR'].sum().reset_index()
winning_nrr_2009
# Out:
#     Winner Team  Winning Team NRR
# 0       England          2.550000
# 1         India          2.413399
# 2       Ireland          0.732418
# 3   Netherlands          0.050000
# 4   New Zealand          5.173519
# 5      Pakistan          7.243681
# 6  South Africa          7.511688
# 7     Sri Lanka          6.145867
# 8   West Indies          5.425035

# %%
losing_nrr_2009 = wc_2009.groupby('Losing Team')['Losing Team NRR'].sum().reset_index()

# %%
total_rnn_2009 = pd.merge(winning_nrr_2009, losing_nrr_2009, how='left', left_on='Winner Team', right_on='Losing Team')

# %%
total_rnn_2009['Net Run Rate'] = total_rnn_2009['Winning Team NRR'] + total_rnn_2009['Losing Team NRR']

# %%
total_rnn_2009
# Out:
#     Winner Team  Winning Team NRR   Losing Team  Losing Team NRR  Net Run Rate
# 0       England          2.550000       England        -2.571429     -0.021429
# 1         India          2.413399         India        -1.578261      0.835138
# 2       Ireland          0.732418       Ireland        -6.451204     -5.718786
# 3   Netherlands          0.050000   Netherlands        -3.374277     -3.324277
# 4   New Zealand          5.173519   New Zealand        -3.703163      1.470356
# 5      Pakistan          7.243681      Pakistan        -3.350000      3.893681
# 6  South Africa          7.511688  South Africa        -0.350000      7.161688
# 7     Sri Lanka          6.145867     Sri Lanka         0.654348      6.800215
# 8   West Indies          5.425035   West Indies        -3.845402      1.579633

# %%
wc_2009
# Out:
#     Match No       Date Group/Semi Final/Final                Match Between  \
# 0          1 2009-05-06                Group B       England vs Netherlands
# 1          2 2009-06-06                Group D      New Zealand vs Scotland
# 2          3 2009-06-06                Group C     Australia vs West Indies
# 3          4 2009-06-06                Group A          Bangladesh vs India
# 4          5 2009-07-06                Group D     Scotland vs South Africa
# 5          6 2009-07-06                Group B          England vs Pakistan
# 6          7 2009-08-06                Group A        Bangladesh vs Ireland
# 7          8 2009-08-06                Group C       Australia vs Sri Lanka
# 8          9 2009-09-06                Group B      Netherlands vs Pakistan
# 9         10 2009-09-06                Group D  New Zealand vs South Africa
# 10        11 2009-10-06                Group C     Sri Lanka vs West Indies
# ...

# %%
wc_2009_groupA_tabel = wc_2009[wc_2009['Group/Semi Final/Final']=='Group A']
wc_2009_groupB_tabel = wc_2009[wc_2009['Group/Semi Final/Final']=='Group B']
wc_2009_groupC_tabel = wc_2009[wc_2009['Group/Semi Final/Final']=='Group C']
wc_2009_groupD_tabel = wc_2009[wc_2009['Group/Semi Final/Final']=='Group D']
wc_2009_groupE_tabel = wc_2009[wc_2009['Group/Semi Final/Final']=='Group E']
wc_2009_groupF_tabel = wc_2009[wc_2009['Group/Semi Final/Final']=='Group F']
wc_2009_semi1_tabel = wc_2009[wc_2009['Group/Semi Final/Final']=='1st Semi Final']
wc_2009_semi2_tabel = wc_2009[wc_2009['Group/Semi Final/Final']=='2nd Semi Final']
wc_2009_final_table = wc_2009[wc_2009['Group/Semi Final/Final']=='Final']

# %% [markdown]
# Group A

# %%
wc_2009_groupA_tabel
# Out:
#     Match No       Date Group/Semi Final/Final          Match Between  \
# 3          4 2009-06-06                Group A    Bangladesh vs India
# 6          7 2009-08-06                Group A  Bangladesh vs Ireland
# 11        12 2009-10-06                Group A       India vs Ireland
#
#                        Venue Winning Team Score Losing Team Score Winner Team  \
# 3   Trent Bridge, Nottingham    180/5(20 overs)   155/8(20 overs)       India
# 6   Trent Bridge, Nottingham  138/4(18.2 overs)   137/8(20 overs)     Ireland
# 11  Trent Bridge, Nottingham  113/2(15.3 overs)   112/8(18 overs)       India
#
#                       Result Player Of The Match       Team1    Team2  \
# 3       India won by 25 runs        Pragyan Ojha  Bangladesh    India
# 6   Ireland won by 6 wickets       Niall O Brien  Bangladesh  Ireland
# 11    India won by 8 wickets         Zaheer Khan       India  Ireland
#
#    Losing Team  Winning Team Runs  Winning Team Over Played  Losing Team Runs  \
# ...

# %%
wc_2009_unique_teamsA = pd.unique(wc_2009_groupA_tabel[['Winner Team','Losing Team']].values.ravel('K'))
wc_2009_unique_teamsA
# Out:
# array(['India', 'Ireland', 'Bangladesh'], dtype=object)

# %%
wc_2009_win_countsA = pd.DataFrame(wc_2009_groupA_tabel['Winner Team'].value_counts()).reset_index()
wc_2009_win_countsA = wc_2009_win_countsA.rename(columns={"index":"Teams", "Winner Team": "Won"})
wc_2009_win_countsA
# Out:
#      Teams  Won
# 0    India    2
# 1  Ireland    1

# %%
wc_2009_groupA_point_table = pd.DataFrame({"Teams":wc_2009_unique_teamsA, "Matches": len(wc_2009_unique_teamsA)-1})
wc_2009_groupA_point_table
# Out:
#         Teams  Matches
# 0       India        2
# 1     Ireland        2
# 2  Bangladesh        2

# %%
wc_2009_groupA_point_table = pd.merge(wc_2009_groupA_point_table, wc_2009_win_countsA, how="left", left_on='Teams', right_on='Teams')
wc_2009_groupA_point_table
# Out:
#         Teams  Matches  Won
# 0       India        2  2.0
# 1     Ireland        2  1.0
# 2  Bangladesh        2  NaN

# %% [markdown]
# below code if it has nan value in above table

# %%
wc_2009_groupA_point_table.fillna(0,inplace=True)
wc_2009_groupA_point_table
# Out:
#         Teams  Matches  Won
# 0       India        2  2.0
# 1     Ireland        2  1.0
# 2  Bangladesh        2  0.0

# %%
wc_2009_groupA_point_table['Loss'] = wc_2009_groupA_point_table['Matches'] - wc_2009_groupA_point_table['Won']
wc_2009_groupA_point_table
# Out:
#         Teams  Matches  Won  Loss
# 0       India        2  2.0   0.0
# 1     Ireland        2  1.0   1.0
# 2  Bangladesh        2  0.0   2.0

# %%
wc_2009_groupA_point_table['Point'] = 2*wc_2009_groupA_point_table['Won']
wc_2009_groupA_point_table
# Out:
#         Teams  Matches  Won  Loss  Point
# 0       India        2  2.0   0.0    4.0
# 1     Ireland        2  1.0   1.0    2.0
# 2  Bangladesh        2  0.0   2.0    0.0

# %%
nrr = pd.merge(wc_2009_groupA_tabel.groupby('Winner Team')['Winning Team NRR'].sum().reset_index(),wc_2009_groupA_tabel.groupby('Losing Team')['Losing Team NRR'].sum().reset_index(), how='outer', left_on='Winner Team', right_on='Losing Team')

# %% [markdown]
# can copy below code as it is

# %%
nrr['Teams'] = nrr['Winner Team'].combine_first(nrr['Losing Team'])
nrr.drop(columns={'Winner Team', 'Losing Team'}, inplace=True)
nrr.fillna(0, inplace=True)
nrr['NRR'] = nrr['Winning Team NRR'] + nrr['Losing Team NRR']
nrr['NRR'] = nrr['Winning Team NRR'] + nrr['Losing Team NRR']
nrr.drop(columns={'Winning Team NRR', 'Losing Team NRR'}, inplace=True)

# %%
nrr
# Out:
#         Teams       NRR
# 0       India  2.413399
# 1     Ireland -0.430981
# 2  Bangladesh -1.982418

# %%
wc_2009_groupA_point_table = pd.merge(wc_2009_groupA_point_table, nrr, on='Teams', how='left')
wc_2009_groupA_point_table
# Out:
#         Teams  Matches  Won  Loss  Point       NRR
# 0       India        2  2.0   0.0    4.0  2.413399
# 1     Ireland        2  1.0   1.0    2.0 -0.430981
# 2  Bangladesh        2  0.0   2.0    0.0 -1.982418

# %% [markdown]
# Group B

# %%
wc_2009_groupB_tabel
# Out:
#    Match No       Date Group/Semi Final/Final            Match Between  \
# 0         1 2009-05-06                Group B   England vs Netherlands
# 5         6 2009-07-06                Group B      England vs Pakistan
# 8         9 2009-09-06                Group B  Netherlands vs Pakistan
#
#                      Venue Winning Team Score Losing Team Score  Winner Team  \
# 0           Lord's, London    163/6(20 overs)   162/5(20 overs)  Netherlands
# 5  Kennington Oval, London    185/5(20 overs)   137/7(20 overs)      England
# 8           Lord's, London    175/5(20 overs)    93(17.3 overs)     Pakistan
#
#                          Result Player Of The Match        Team1        Team2  \
# 0  Netherlands won by 4 wickets       Tom de Grooth      England  Netherlands
# 5        England won by 48 runs         Luke Wright      England     Pakistan
# 8       Pakistan won by 82 runs        Kamran Akmal  Netherlands     Pakistan
#
# ...

# %%
wc_2009_unique_teamsB = pd.unique(wc_2009_groupB_tabel[['Winner Team','Losing Team']].values.ravel('K'))
wc_2009_unique_teamsB
# Out:
# array(['Netherlands', 'England', 'Pakistan'], dtype=object)

# %%
wc_2009_win_countsB = pd.DataFrame(wc_2009_groupB_tabel['Winner Team'].value_counts()).reset_index()
wc_2009_win_countsB = wc_2009_win_countsB.rename(columns={"index":"Teams", "Winner Team": "Won"})
wc_2009_win_countsB
# Out:
#          Teams  Won
# 0  Netherlands    1
# 1      England    1
# 2     Pakistan    1

# %%
wc_2009_groupB_point_table = pd.DataFrame({"Teams":wc_2009_unique_teamsB, "Matches": len(wc_2009_unique_teamsB)-1})
wc_2009_groupB_point_table
# Out:
#          Teams  Matches
# 0  Netherlands        2
# 1      England        2
# 2     Pakistan        2

# %%
wc_2009_groupB_point_table = pd.merge(wc_2009_groupB_point_table, wc_2009_win_countsB, how="left", left_on='Teams', right_on='Teams')
wc_2009_groupB_point_table
# Out:
#          Teams  Matches  Won
# 0  Netherlands        2    1
# 1      England        2    1
# 2     Pakistan        2    1

# %%
wc_2009_groupB_point_table['Loss'] = wc_2009_groupB_point_table['Matches'] - wc_2009_groupB_point_table['Won']

# %%
wc_2009_groupB_point_table['Point'] = 2*wc_2009_groupB_point_table['Won']
wc_2009_groupB_point_table
# Out:
#          Teams  Matches  Won  Loss  Point
# 0  Netherlands        2    1     1      2
# 1      England        2    1     1      2
# 2     Pakistan        2    1     1      2

# %%
nrr = pd.merge(wc_2009_groupB_tabel.groupby('Winner Team')['Winning Team NRR'].sum().reset_index(),wc_2009_groupB_tabel.groupby('Losing Team')['Losing Team NRR'].sum().reset_index(), how='outer', left_on='Winner Team', right_on='Losing Team')

# %%
nrr['Teams'] = nrr['Winner Team'].combine_first(nrr['Losing Team'])
nrr.drop(columns={'Winner Team', 'Losing Team'}, inplace=True)
nrr.fillna(0, inplace=True)
nrr['NRR'] = nrr['Winning Team NRR'] + nrr['Losing Team NRR']
nrr['NRR'] = nrr['Winning Team NRR'] + nrr['Losing Team NRR']
nrr.drop(columns={'Winning Team NRR', 'Losing Team NRR'}, inplace=True)

# %%
nrr
# Out:
#          Teams       NRR
# 0      England  2.350000
# 1  Netherlands -3.324277
# 2     Pakistan  0.974277

# %%
wc_2009_groupB_point_table = pd.merge(wc_2009_groupB_point_table, nrr, on='Teams', how='left')
wc_2009_groupB_point_table
# Out:
#          Teams  Matches  Won  Loss  Point       NRR
# 0  Netherlands        2    1     1      2 -3.324277
# 1      England        2    1     1      2  2.350000
# 2     Pakistan        2    1     1      2  0.974277

# %%
wc_2009_groupB_point_table = wc_2009_groupB_point_table.sort_values('NRR', ascending=False).reset_index(drop=True)
wc_2009_groupB_point_table
# Out:
#          Teams  Matches  Won  Loss  Point       NRR
# 0      England        2    1     1      2  2.350000
# 1     Pakistan        2    1     1      2  0.974277
# 2  Netherlands        2    1     1      2 -3.324277

# %% [markdown]
# Group C

# %%
wc_2009_groupC_tabel
# Out:
#     Match No       Date Group/Semi Final/Final             Match Between  \
# 2          3 2009-06-06                Group C  Australia vs West Indies
# 7          8 2009-08-06                Group C    Australia vs Sri Lanka
# 10        11 2009-10-06                Group C  Sri Lanka vs West Indies
#
#                        Venue Winning Team Score Losing Team Score  \
# 2    Kennington Oval, London  172/3(15.5 overs)   169/7(20 overs)
# 7   Trent Bridge, Nottingham    160/4(19 overs)   159/9(20 overs)
# 10  Trent Bridge, Nottingham    192/5(20 overs)   177/5(20 overs)
#
#     Winner Team                        Result Player Of The Match      Team1  \
# 2   West Indies  West Indies won by 7 wickets         Chris Gayle  Australia
# 7     Sri Lanka    Sri Lanka won by 6 wickets    Kumar Sangakkara  Australia
# 10    Sri Lanka      Sri Lanka won by 15 runs   Sanath Jayasuriya  Sri Lanka
#
#           Team2  Losing Team  Winning Team Runs  Winning Team Over Played  \
# ...

# %%
wc_2009_unique_teamsC = pd.unique(wc_2009_groupC_tabel[['Winner Team','Losing Team']].values.ravel('K'))
wc_2009_unique_teamsC
# Out:
# array(['West Indies', 'Sri Lanka', 'Australia'], dtype=object)

# %%
wc_2009_win_countsC = pd.DataFrame(wc_2009_groupC_tabel['Winner Team'].value_counts()).reset_index()
wc_2009_win_countsC = wc_2009_win_countsC.rename(columns={"index":"Teams", "Winner Team": "Won"})
wc_2009_win_countsC
# Out:
#          Teams  Won
# 0    Sri Lanka    2
# 1  West Indies    1

# %%
wc_2009_groupC_point_table = pd.DataFrame({"Teams":wc_2009_unique_teamsC, "Matches": len(wc_2009_unique_teamsC)-1})
wc_2009_groupC_point_table
# Out:
#          Teams  Matches
# 0  West Indies        2
# 1    Sri Lanka        2
# 2    Australia        2

# %%
wc_2009_groupC_point_table = pd.merge(wc_2009_groupC_point_table, wc_2009_win_countsC, how="left", left_on='Teams', right_on='Teams')
wc_2009_groupC_point_table
# Out:
#          Teams  Matches  Won
# 0  West Indies        2  1.0
# 1    Sri Lanka        2  2.0
# 2    Australia        2  NaN

# %%
wc_2009_groupC_point_table.fillna(0,inplace=True)
wc_2009_groupC_point_table
# Out:
#          Teams  Matches  Won
# 0  West Indies        2  1.0
# 1    Sri Lanka        2  2.0
# 2    Australia        2  0.0

# %%
wc_2009_groupC_point_table['Loss'] = wc_2009_groupC_point_table['Matches'] - wc_2009_groupC_point_table['Won']

# %%
wc_2009_groupC_point_table['Point'] = 2*wc_2009_groupC_point_table['Won']
wc_2009_groupC_point_table
# Out:
#          Teams  Matches  Won  Loss  Point
# 0  West Indies        2  1.0   1.0    2.0
# 1    Sri Lanka        2  2.0   0.0    4.0
# 2    Australia        2  0.0   2.0    0.0

# %%
nrr = pd.merge(wc_2009_groupC_tabel.groupby('Winner Team')['Winning Team NRR'].sum().reset_index(),wc_2009_groupC_tabel.groupby('Losing Team')['Losing Team NRR'].sum().reset_index(), how='outer', left_on='Winner Team', right_on='Losing Team')

# %%
nrr['Teams'] = nrr['Winner Team'].combine_first(nrr['Losing Team'])
nrr.drop(columns={'Winner Team', 'Losing Team'}, inplace=True)
nrr.fillna(0, inplace=True)
nrr['NRR'] = nrr['Winning Team NRR'] + nrr['Losing Team NRR']
nrr['NRR'] = nrr['Winning Team NRR'] + nrr['Losing Team NRR']
nrr.drop(columns={'Winning Team NRR', 'Losing Team NRR'}, inplace=True)

# %%
nrr
# Out:
#          Teams       NRR
# 0    Sri Lanka  1.221053
# 1  West Indies  1.896774
# 2    Australia -3.117827

# %%
wc_2009_groupC_point_table = pd.merge(wc_2009_groupC_point_table, nrr, on='Teams', how='left')
wc_2009_groupC_point_table
# Out:
#          Teams  Matches  Won  Loss  Point       NRR
# 0  West Indies        2  1.0   1.0    2.0  1.896774
# 1    Sri Lanka        2  2.0   0.0    4.0  1.221053
# 2    Australia        2  0.0   2.0    0.0 -3.117827

# %%
wc_2009_groupC_point_table = wc_2009_groupC_point_table.sort_values('Point', ascending=False).reset_index(drop=True)
wc_2009_groupC_point_table
# Out:
#          Teams  Matches  Won  Loss  Point       NRR
# 0    Sri Lanka        2  2.0   0.0    4.0  1.221053
# 1  West Indies        2  1.0   1.0    2.0  1.896774
# 2    Australia        2  0.0   2.0    0.0 -3.117827

# %% [markdown]
# Group D

# %%
wc_2009_groupD_tabel
# Out:
#    Match No       Date Group/Semi Final/Final                Match Between  \
# 1         2 2009-06-06                Group D      New Zealand vs Scotland
# 4         5 2009-07-06                Group D     Scotland vs South Africa
# 9        10 2009-09-06                Group D  New Zealand vs South Africa
#
#                      Venue Winning Team Score Losing Team Score   Winner Team  \
# 1  Kennington Oval, London      90/3(6 overs)     89/4(7 overs)   New Zealand
# 4  Kennington Oval, London    211/5(20 overs)    81(15.4 overs)  South Africa
# 9           Lord's, London    128/7(20 overs)   127/5(20 overs)  South Africa
#
#                          Result   Player Of The Match        Team1  \
# 1  New Zealand won by 7 wickets            Ian Butler  New Zealand
# 4  South Africa won by 130 runs        AB de Villiers     Scotland
# 9     South Africa won by 1 run  Roelof van der Merwe  New Zealand
#
#           Team2  Losing Team  Winning Team Runs  Winning Team Over Played  \
# ...

# %%
wc_2009_unique_teamsD = pd.unique(wc_2009_groupD_tabel[['Winner Team','Losing Team']].values.ravel('K'))
wc_2009_unique_teamsD
# Out:
# array(['New Zealand', 'South Africa', 'Scotland'], dtype=object)

# %%
wc_2009_win_countsD = pd.DataFrame(wc_2009_groupD_tabel['Winner Team'].value_counts()).reset_index()
wc_2009_win_countsD = wc_2009_win_countsD.rename(columns={"index":"Teams", "Winner Team": "Won"})
wc_2009_win_countsD
# Out:
#           Teams  Won
# 0  South Africa    2
# 1   New Zealand    1

# %%
wc_2009_groupD_point_table = pd.DataFrame({"Teams":wc_2009_unique_teamsD, "Matches": len(wc_2009_unique_teamsD)-1})
wc_2009_groupD_point_table
# Out:
#           Teams  Matches
# 0   New Zealand        2
# 1  South Africa        2
# 2      Scotland        2

# %%
wc_2009_groupD_point_table = pd.merge(wc_2009_groupD_point_table, wc_2009_win_countsD, how="left", left_on='Teams', right_on='Teams')
wc_2009_groupD_point_table
# Out:
#           Teams  Matches  Won
# 0   New Zealand        2  1.0
# 1  South Africa        2  2.0
# 2      Scotland        2  NaN

# %%
wc_2009_groupD_point_table.fillna(0,inplace=True)
wc_2009_groupD_point_table
# Out:
#           Teams  Matches  Won
# 0   New Zealand        2  1.0
# 1  South Africa        2  2.0
# 2      Scotland        2  0.0

# %%
wc_2009_groupD_point_table['Loss'] = wc_2009_groupD_point_table['Matches'] - wc_2009_groupD_point_table['Won']

# %%
wc_2009_groupD_point_table['Point'] = 2*wc_2009_groupD_point_table['Won']
wc_2009_groupD_point_table
# Out:
#           Teams  Matches  Won  Loss  Point
# 0   New Zealand        2  1.0   1.0    2.0
# 1  South Africa        2  2.0   0.0    4.0
# 2      Scotland        2  0.0   2.0    0.0

# %%
nrr = pd.merge(wc_2009_groupD_tabel.groupby('Winner Team')['Winning Team NRR'].sum().reset_index(),wc_2009_groupD_tabel.groupby('Losing Team')['Losing Team NRR'].sum().reset_index(), how='outer', left_on='Winner Team', right_on='Losing Team')

# %%
nrr['Teams'] = nrr['Winner Team'].combine_first(nrr['Losing Team'])
nrr.drop(columns={'Winner Team', 'Losing Team'}, inplace=True)
nrr.fillna(0, inplace=True)
nrr['NRR'] = nrr['Winning Team NRR'] + nrr['Losing Team NRR']
nrr['NRR'] = nrr['Winning Team NRR'] + nrr['Losing Team NRR']
nrr.drop(columns={'Winning Team NRR', 'Losing Team NRR'}, inplace=True)

# %%
nrr
# Out:
#           Teams       NRR
# 0   New Zealand  2.235714
# 1  South Africa  5.340260
# 2      Scotland -7.575974

# %%
wc_2009_groupD_point_table = pd.merge(wc_2009_groupD_point_table, nrr, on='Teams', how='left')
wc_2009_groupD_point_table
# Out:
#           Teams  Matches  Won  Loss  Point       NRR
# 0   New Zealand        2  1.0   1.0    2.0  2.235714
# 1  South Africa        2  2.0   0.0    4.0  5.340260
# 2      Scotland        2  0.0   2.0    0.0 -7.575974

# %%
wc_2009_groupD_point_table = wc_2009_groupD_point_table.sort_values('Point', ascending=False).reset_index(drop=True)
wc_2009_groupD_point_table
# Out:
#           Teams  Matches  Won  Loss  Point       NRR
# 0  South Africa        2  2.0   0.0    4.0  5.340260
# 1   New Zealand        2  1.0   1.0    2.0  2.235714
# 2      Scotland        2  0.0   2.0    0.0 -7.575974

# %% [markdown]
# Group E

# %%
wc_2009_groupE_tabel
# Out:
#     Match No       Date Group/Semi Final/Final                Match Between  \
# 13        14 2009-11-06                Group E      England vs South Africa
# 15        16 2009-12-06                Group E         India vs West Indies
# 16        17 2009-06-13                Group E  South Africa vs West Indies
# 19        20 2009-06-14                Group E             England vs India
# 21        22 2009-06-15                Group E       England vs West Indies
# 23        24 2009-06-16                Group E        India vs South Africa
#
#                        Venue Winning Team Score Losing Team Score  \
# 13  Trent Bridge, Nottingham  114/3(18.2 overs)   111(19.5 overs)
# 15            Lord's, London  156/3(18.4 overs)   153/7(20 overs)
# 16   Kennington Oval, London    183/7(20 overs)   163/9(20 overs)
# 19            Lord's, London    153/7(20 overs)   150/5(20 overs)
# 21   Kennington Oval, London    82/5(8.2 overs)   161/6(20 overs)
# ...

# %%
wc_2009_unique_teamsE = pd.unique(wc_2009_groupE_tabel[['Winner Team','Losing Team']].values.ravel('K'))
wc_2009_unique_teamsE
# Out:
# array(['South Africa', 'West Indies', 'England', 'India'], dtype=object)

# %%
wc_2009_win_countsE = pd.DataFrame(wc_2009_groupE_tabel['Winner Team'].value_counts()).reset_index()
wc_2009_win_countsE = wc_2009_win_countsE.rename(columns={"index":"Teams", "Winner Team": "Won"})
wc_2009_win_countsE
# Out:
#           Teams  Won
# 0  South Africa    3
# 1   West Indies    2
# 2       England    1

# %%
wc_2009_groupE_point_table = pd.DataFrame({"Teams":wc_2009_unique_teamsE, "Matches": len(wc_2009_unique_teamsE)-1})
wc_2009_groupE_point_table
# Out:
#           Teams  Matches
# 0  South Africa        3
# 1   West Indies        3
# 2       England        3
# 3         India        3

# %%
wc_2009_groupE_point_table = pd.merge(wc_2009_groupE_point_table, wc_2009_win_countsE, how="left", left_on='Teams', right_on='Teams')
wc_2009_groupE_point_table
# Out:
#           Teams  Matches  Won
# 0  South Africa        3  3.0
# 1   West Indies        3  2.0
# 2       England        3  1.0
# 3         India        3  NaN

# %%
wc_2009_groupE_point_table.fillna(0,inplace=True)
wc_2009_groupE_point_table
# Out:
#           Teams  Matches  Won
# 0  South Africa        3  3.0
# 1   West Indies        3  2.0
# 2       England        3  1.0
# 3         India        3  0.0

# %%
wc_2009_groupE_point_table['Loss'] = wc_2009_groupE_point_table['Matches'] - wc_2009_groupE_point_table['Won']

# %%
wc_2009_groupE_point_table['Point'] = 2*wc_2009_groupE_point_table['Won']
wc_2009_groupE_point_table
# Out:
#           Teams  Matches  Won  Loss  Point
# 0  South Africa        3  3.0   0.0    6.0
# 1   West Indies        3  2.0   1.0    4.0
# 2       England        3  1.0   2.0    2.0
# 3         India        3  0.0   3.0    0.0

# %%
nrr = pd.merge(wc_2009_groupE_tabel.groupby('Winner Team')['Winning Team NRR'].sum().reset_index(),wc_2009_groupE_tabel.groupby('Losing Team')['Losing Team NRR'].sum().reset_index(), how='outer', left_on='Winner Team', right_on='Losing Team')

# %%
nrr['Teams'] = nrr['Winner Team'].combine_first(nrr['Losing Team'])
nrr.drop(columns={'Winner Team', 'Losing Team'}, inplace=True)
nrr.fillna(0, inplace=True)
nrr['NRR'] = nrr['Winning Team NRR'] + nrr['Losing Team NRR']
nrr['NRR'] = nrr['Winning Team NRR'] + nrr['Losing Team NRR']
nrr.drop(columns={'Winning Team NRR', 'Losing Team NRR'}, inplace=True)

# %%
nrr
# Out:
#           Teams       NRR
# 0       England -2.371429
# 1  South Africa  2.171429
# 2   West Indies  1.778261
# 3         India -1.578261

# %%
wc_2009_groupE_point_table = pd.merge(wc_2009_groupE_point_table, nrr, on='Teams', how='left')
wc_2009_groupE_point_table
# Out:
#           Teams  Matches  Won  Loss  Point       NRR
# 0  South Africa        3  3.0   0.0    6.0  2.171429
# 1   West Indies        3  2.0   1.0    4.0  1.778261
# 2       England        3  1.0   2.0    2.0 -2.371429
# 3         India        3  0.0   3.0    0.0 -1.578261

# %% [markdown]
# Group F

# %%
wc_2009_groupF_tabel
# Out:
#     Match No       Date Group/Semi Final/Final             Match Between  \
# 12        13 2009-11-06                Group F    Ireland vs New Zealand
# 14        15 2009-12-06                Group F     Pakistan vs Sri Lanka
# 17        18 2009-06-13                Group F   New Zealand vs Pakistan
# 18        19 2009-06-14                Group F      Ireland vs Sri Lanka
# 20        21 2009-06-15                Group F       Ireland vs Pakistan
# 22        23 2009-06-16                Group F  New Zealand vs Sri Lanka
#
#                        Venue Winning Team Score Losing Team Score  \
# 12  Trent Bridge, Nottingham    198/5(20 overs)   115(16.4 overs)
# 14            Lord's, London    150/7(20 overs)   131/9(20 overs)
# 17   Kennington Oval, London  100/4(13.1 overs)    99(18.3 overs)
# 18            Lord's, London    144/9(20 overs)   135/7(20 overs)
# 20   Kennington Oval, London    159/5(20 overs)   120/9(20 overs)
# ...

# %%
wc_2009_unique_teamsF = pd.unique(wc_2009_groupF_tabel[['Winner Team','Losing Team']].values.ravel('K'))
wc_2009_unique_teamsF
# Out:
# array(['New Zealand', 'Sri Lanka', 'Pakistan', 'Ireland'], dtype=object)

# %%
wc_2009_win_countsF = pd.DataFrame(wc_2009_groupF_tabel['Winner Team'].value_counts()).reset_index()
wc_2009_win_countsF = wc_2009_win_countsF.rename(columns={"index":"Teams", "Winner Team": "Won"})
wc_2009_win_countsF
# Out:
#          Teams  Won
# 0    Sri Lanka    3
# 1     Pakistan    2
# 2  New Zealand    1

# %%
wc_2009_groupF_point_table = pd.DataFrame({"Teams":wc_2009_unique_teamsF, "Matches": len(wc_2009_unique_teamsF)-1})
wc_2009_groupF_point_table
# Out:
#          Teams  Matches
# 0  New Zealand        3
# 1    Sri Lanka        3
# 2     Pakistan        3
# 3      Ireland        3

# %%
wc_2009_groupF_point_table = pd.merge(wc_2009_groupF_point_table, wc_2009_win_countsF, how="left", left_on='Teams', right_on='Teams')
wc_2009_groupF_point_table
# Out:
#          Teams  Matches  Won
# 0  New Zealand        3  1.0
# 1    Sri Lanka        3  3.0
# 2     Pakistan        3  2.0
# 3      Ireland        3  NaN

# %%
wc_2009_groupF_point_table.fillna(0,inplace=True)
wc_2009_groupF_point_table
# Out:
#          Teams  Matches  Won
# 0  New Zealand        3  1.0
# 1    Sri Lanka        3  3.0
# 2     Pakistan        3  2.0
# 3      Ireland        3  0.0

# %%
wc_2009_groupF_point_table['Loss'] = wc_2009_groupF_point_table['Matches'] - wc_2009_groupF_point_table['Won']

# %%
wc_2009_groupF_point_table['Point'] = 2*wc_2009_groupF_point_table['Won']
wc_2009_groupF_point_table
# Out:
#          Teams  Matches  Won  Loss  Point
# 0  New Zealand        3  1.0   2.0    2.0
# 1    Sri Lanka        3  3.0   0.0    6.0
# 2     Pakistan        3  2.0   1.0    4.0
# 3      Ireland        3  0.0   3.0    0.0

# %%
nrr = pd.merge(wc_2009_groupF_tabel.groupby('Winner Team')['Winning Team NRR'].sum().reset_index(),wc_2009_groupF_tabel.groupby('Losing Team')['Losing Team NRR'].sum().reset_index(), how='outer', left_on='Winner Team', right_on='Losing Team')

# %%
nrr['Teams'] = nrr['Winner Team'].combine_first(nrr['Losing Team'])
nrr.drop(columns={'Winner Team', 'Losing Team'}, inplace=True)
nrr.fillna(0, inplace=True)
nrr['NRR'] = nrr['Winning Team NRR'] + nrr['Losing Team NRR']
nrr['NRR'] = nrr['Winning Team NRR'] + nrr['Losing Team NRR']
nrr.drop(columns={'Winning Team NRR', 'Losing Team NRR'}, inplace=True)

# %%
nrr
# Out:
#          Teams       NRR
# 0  New Zealand -0.765359
# 1     Pakistan  3.223752
# 2    Sri Lanka  2.829412
# 3      Ireland -5.287805

# %%
wc_2009_groupF_point_table = pd.merge(wc_2009_groupF_point_table, nrr, on='Teams', how='left')
wc_2009_groupF_point_table
# Out:
#          Teams  Matches  Won  Loss  Point       NRR
# 0  New Zealand        3  1.0   2.0    2.0 -0.765359
# 1    Sri Lanka        3  3.0   0.0    6.0  2.829412
# 2     Pakistan        3  2.0   1.0    4.0  3.223752
# 3      Ireland        3  0.0   3.0    0.0 -5.287805

# %%
wc_2009_groupF_point_table = wc_2009_groupF_point_table.sort_values('Point', ascending=False).reset_index(drop=True)
wc_2009_groupF_point_table
# Out:
#          Teams  Matches  Won  Loss  Point       NRR
# 0    Sri Lanka        3  3.0   0.0    6.0  2.829412
# 1     Pakistan        3  2.0   1.0    4.0  3.223752
# 2  New Zealand        3  1.0   2.0    2.0 -0.765359
# 3      Ireland        3  0.0   3.0    0.0 -5.287805
